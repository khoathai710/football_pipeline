# %%
import pandas as pd

# %%
df = pd.read_parquet(r"C:\Users\thaia\Downloads\teams_dataset.parquet")

# %%
df
# Out:
#    team_id                      name  \
# 0       54                    Fulham
# 1        3                   Arsenal
# 2        7               Aston Villa
# 3       91               Bournemouth
# 4       94                 Brentford
# 5       36  Brighton and Hove Albion
# 6       90                   Burnley
# 7        8                   Chelsea
# 8       31            Crystal Palace
# 9       11                   Everton
# 10       2              Leeds United
# 11      14                 Liverpool
# 12      43           Manchester City
# 13       1         Manchester United
# 14       4          Newcastle United
# 15      17         Nottingham Forest
# 16      56                Sunderland
# 17       6         Tottenham Hotspur
# 18      21           West Ham United
# 19      39   Wolverhampton Wanderers
#
#                                                  link   est  \
# 0                           https://www.fulhamfc.com/  1879
# ...
